# %%
import csv
import numpy as np
import pandas
import matplotlib.pyplot as plt

log_data = []

with open(f"data/pressure_one.csv") as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')
    for row in spamreader:
        log_data.append(row)

# %%
log_data = np.array(log_data, dtype=np.float32)

pandas.DataFrame(log_data)
# Out:
#              0       1         2           3           4         5    6  \
# 0     0.001043  3720.0  0.005951  142.243896 -242.527344  0.616423  0.0
# 1     0.002063  3720.0  0.019389  142.241852 -242.525009  0.602373  0.0
# 2     0.003128  3720.0  0.034090  142.237183 -242.516037  0.582213  0.0
# 3     0.004218  3720.0  0.047658  142.230316 -242.503143  0.560545  0.0
# 4     0.005338  3720.0  0.062709  142.219879 -242.490677  0.540922  0.0
# ...        ...     ...       ...         ...         ...       ...  ...
# 2642  3.303000  2720.0  0.000016  130.842758 -238.397339  1.887162  0.0
# 2643  3.304250  2720.0  0.000018  130.842926 -238.396927  1.887097  0.0
# 2644  3.305501  2720.0  0.000020  130.843155 -238.397171  1.887007  0.0
# 2645  3.306751  2720.0  0.000022  130.843369 -238.397720  1.886871  0.0
# 2646  3.308002  2820.0  0.000025  130.843597 -238.397888  1.886780  0.0
#
#              7
# 0     5.109323
# 1     5.193178
# 2     5.323396
# 3     5.468987
# 4     5.591577
# ...        ...
# 2642  6.652588
# 2643  6.652336
# 2644  6.652915
# 2645  6.653362
# 2646  6.653840
#
# [2647 rows x 8 columns]

# %%
font_size = 18
plt.rcParams['font.size'] = '14'

# %%
plt.rcParams['figure.figsize'] = [16, 10]

data = log_data[0:2400]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(data[:, 0], data[:, 7], linewidth=3, label="Maksymalne ciśnienie")

ax.set_ylabel("Ciśnienie [ Pa ]", fontsize=font_size)
ax.set_xlabel("Czas [ s ]", fontsize=font_size)

plt.show()

# %%
# import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize'] = [16, 10]
# plt.rcParams['font.size'] = '16'

# data = log_data[0:120]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(data[:, 0], data[:, 3], color='magenta', linewidth=4, label="Energia potencjalna grawitacji")
ax.plot(data[:, 0], data[:, 2], color='dodgerblue', linewidth=2, label="Energia kinetyczna")
ax.plot(data[:, 0], data[:, 4], color='lime', linewidth=2, label="Energia potencjalna LJ wewnątrz obiektów")
ax.plot(data[:, 0], data[:, 5], color='orange', linewidth=3, label="Energia potencjalna odpychająca LJ pomiędzy obiektami a podłożem")
ax.plot(data[:, 0], data[:, 6], color='red', linewidth=3, label="Energia potencjalna odpychająca LJ pomiędzy obiektami")
ax.plot(data[:, 0], data[:, 4] + data[:, 3] + data[:, 2] + data[:, 5] + data[:, 6], color='black', linewidth=3, label="Enegria całkowita")

font_size = 20
# ax.set_title("Zmiana enegii w czasie dla układu złożonego z dwóch obiektów i podłoża", fontsize=font_size)
ax.set_ylabel("Energia [ J ]", fontsize=font_size)
ax.set_xlabel("Czas [ s ]", fontsize=font_size)
ax.legend(bbox_to_anchor = [0.34, 0.93], fontsize=font_size-5)

plt.show()
